# %%
import pandas as pd

import matplotlib.pyplot as plt   
from pandas.plotting import register_matplotlib_converters
from utilities.base import BaseData
from utilities.utils import geo_mean, sum_day
register_matplotlib_converters()

# %%
df = BaseData().get_filled_df()
df.head(1)
# Out:
#           date  type  category_id  \
# id
# 0   2019-02-01  food           10
#
#                                        category_title  \
# id
# 0   Молоко питьевое цельное пастеризованное 2,5-3,...
#
#                                            site_title  price_old site_unit  \
# id
# 0   Молоко питьевое цельное пастеризованное 2,5-3,...       -1.0         л
#
#    site_link site_code  miss  price_new  nsprice_f
# id
# 0     109549       gks     0      55.17      55.17

# %%
df.loc[df.site_code=='vprok',:].iloc[:20]
# Out:
#              date  type  category_id  \
# id
# 75939  2020-10-14  food           10
# 75940  2020-10-15  food           10
# 75941  2020-10-16  food           10
# 75942  2020-10-17  food           10
# 75943  2020-10-18  food           10
# 75944  2020-10-19  food           10
# 75945  2020-10-20  food           10
# 75946  2020-10-21  food           10
# 75947  2020-10-22  food           10
# 75948  2020-10-23  food           10
# 75949  2020-10-24  food           10
# 75950  2020-10-25  food           10
# 75951  2020-10-26  food           10
# 75952  2020-10-27  food           10
# 75953  2020-10-28  food           10
# 75954  2020-10-29  food           10
# 75955  2020-10-30  food           10
# 75956  2020-10-31  food           10
# 75957  2020-11-01  food           10
# 75958  2020-11-02  food           10
#
#                                           category_title  \
# id
# 75939  Молоко питьевое цельное пастеризованное 2,5-3,...
# ...

# %%
df = df[df.category_id!=76]
df = df[df.site_code!='ozon']

df.loc[:,'unq'] = df.category_id.astype(str) + df.site_link
df.loc[:,'date'] = pd.to_datetime(df.date)
df = df[df.miss==0]

df = df.drop(columns=['category_title','site_title','site_unit',
                      'site_link','price_new','miss','price_old','site_code'])
df.head(1)
# Out:
#          date  type  category_id  nsprice_f       unq
# id
# 0  2019-02-01  food           10      55.17  10109549

# %%
type_ = 'food'
df = df[df.type==type_]

srs = df.groupby('unq')['nsprice_f'].transform(lambda x: x.pct_change()+1)
df.loc[:,'cng_price'] = srs
# df = df.drop(columns=['nsprice_f'])

pvt_df = df.pivot_table(index='date', columns='category_id', aggfunc=geo_mean).loc[:,'cng_price'].iloc[1:]
pvt_df.iloc[0,:] = 1
pvt_df = pvt_df.fillna(method='ffill').apply(lambda x: x.cumprod(), axis=0).dropna(how='all')
# Out:
# /Users/user/Desktop/RANEPA_lec_24_03/venv/lib/python3.9/site-packages/pandas/core/reshape/pivot.py:165: FutureWarning: Dropping invalid columns in DataFrameGroupBy.agg is deprecated. In a future version, a TypeError will be raised. Before calling .agg, select only columns which should be valid for the aggregating function.
#   agged = grouped.agg(aggfunc)
# /Users/user/Desktop/RANEPA_lec_24_03/utilities/utils.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   return a.prod()**(1.0/len(a))

# %%
df
# Out:
#               date  type  category_id  nsprice_f  \
# id
# 0       2019-02-01  food           10      55.17
# 28      2019-03-01  food           10      55.37
# 59      2019-04-01  food           10      55.58
# 89      2019-05-01  food           10      55.72
# 120     2019-06-01  food           10      55.78
# ...            ...   ...          ...        ...
# 2533995 2019-06-29  food            9      61.90
# 2533996 2019-06-30  food            9      61.90
# 2533998 2019-07-02  food            9      61.90
# 2533999 2019-07-03  food            9      61.90
# 2534000 2019-07-04  food            9      61.90
#
#                                                        unq  cng_price
# id
# 0                                                 10109549        NaN
# 28                                                10109549   1.003625
# 59                                                10109549   1.003793
# 89                                                10109549   1.002519
# ...

# %%
wt_srs = pd.read_csv(r'~/PycharmProjects/ane_django/parser_app/logic/description/categories.csv', index_col='id', sep=';').iloc[:-1,:]['cpi_weight']
wt_srs.index = wt_srs.index.astype(int)
cpi_online = pvt_df.apply(lambda srs: sum_day(wt_srs,srs), axis=1)

# %%
cpi_of = pd.read_csv(f'~/cpi_food.csv', index_col=0, sep=';')
cpi_of.index = pd.to_datetime(cpi_of.index,format=r'%d.%m.%Y')
cpi_of.iloc[0] = 1
cpi_of = cpi_of.cumprod()
date_srs = pd.Series(index=pd.date_range(start=cpi_online.index[0], end=cpi_online.index[-1])).to_frame().drop(columns=0)
cpi_of = cpi_of.merge(date_srs, left_index=True, right_index=True, how='right').fillna(method='bfill')['cpi'] # change to bfill
# Out:
# /var/folders/c0/88ft1w2s0j58fqydt5bs54bh0000gn/T/ipykernel_6935/690325177.py:5: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   date_srs = pd.Series(index=pd.date_range(start=cpi_online.index[0], end=cpi_online.index[-1])).to_frame().drop(columns=0)

# %% [markdown]
# # ИПЦ Онлайн VS Росстат

# %%
fig, ax1 = plt.subplots(figsize=(9,6)) # plt.subplots(figsize=(9,6))
# cond1 = (cpi_online.index>'2020-03-01')&(cpi_online.index<'2020-06-20')
ax1.set_ylabel('Индекс цен (онлайн-ритейлеры)')
ax1.plot((cpi_online*100).rolling(30).mean(), lw=2);
# ax1.plot((cpi_online*100), lw=2);
# ax1.plot(cpi_of, color=color_cpi, ls='--', lw=3);
ax1.tick_params(axis='y')

ax2 = ax1.twinx()
ax2.set_ylabel('ИПЦ Росстата')
ax2.plot(cpi_of*100, ls='-', color="#ff7f0e",lw=2);
ax2.tick_params(axis='y')

fig.legend(['Индекс цен продовольственных онлайн-ритейлеров','ИПЦ на продовольственные товары Росстата'], loc='upper left', bbox_to_anchor=(0.09,0.95))
fig.tight_layout()

# plt.grid(axis='y')
plt.show()

# %%
date_srs = pd.Series(index=pd.date_range(start=cpi_online.index[0], end=cpi_online.index[-1])).to_frame().drop(columns=0)
cpi_online.name = 'cpi_online'
((cpi_online).to_frame().merge(date_srs, left_index=True, right_index=True, how='right').fillna(method='bfill')*100).to_excel('~/cpi_online.xlsx') # change to bfill
# Out:
# /var/folders/c0/88ft1w2s0j58fqydt5bs54bh0000gn/T/ipykernel_6935/1255845699.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   date_srs = pd.Series(index=pd.date_range(start=cpi_online.index[0], end=cpi_online.index[-1])).to_frame().drop(columns=0)

# %%
# save fig in pdf

fig.savefig("./plots/cpi_online_vs_rosstat.pdf", bbox_inches='tight')

# %%
cpi_online = cpi_online.reindex(cpi_of.index).fillna(method='ffill')

# %%
df = pd.DataFrame(data=[cpi_online, cpi_of]).transpose()
df.columns = ["cpi_online", "cpi_gks"]

# %%
df.fillna(method='ffill')
# Out:
#             cpi_online  cpi_gks
# 2019-02-01    1.000000  1.01070
# 2019-02-02    1.003908  1.01070
# 2019-02-03    1.003908  1.01070
# 2019-02-04    1.007858  1.01070
# 2019-02-05    1.012493  1.01070
# ...                ...      ...
# 2024-02-02    1.869246  1.35724
# 2024-02-03    1.881417  1.35724
# 2024-02-04    1.881417  1.35724
# 2024-02-05    1.883804  1.35724
# 2024-02-06    1.883804  1.35724
#
# [1832 rows x 2 columns]

# %%
df.to_excel('./plots/prod_cpi.xlsx', index=True)

# %%
cpi_online.tail()
# Out:
# 2024-02-02    1.869246
# 2024-02-03    1.881417
# 2024-02-04    1.881417
# 2024-02-05    1.883804
# 2024-02-06    1.883804
# Freq: D, Name: cpi_online, dtype: float64

# %%
# this code for export to excel
from sqlalchemy import create_engine
# pvt_df = pvt_df.loc[:,~pvt_df.columns.isin([6, 12, 21, 33])]

PATH_TO_BASE = r'mysql+pymysql://root:Fokina12@localhost/ane_base'
engine = create_engine(PATH_TO_BASE)
df_categories = pd.read_sql(sql='SELECT * FROM parser_app_category_titles', con=engine)
categories_dict = df_categories.set_index('category_id')['category_title'].to_dict()
pvt_df = pvt_df.rename(columns=categories_dict)
last_date = cpi_online.index[-1]
pvt_df.reindex(pd.date_range(start='2019-02-01', end=last_date), method='ffill').to_excel('online_indexes.xlsx')

# %%
pvt_df
# Out:
# category_id  Говядина (кроме бескостного мяса)  \
# date
# 2019-02-01                            1.000000
# 2019-02-02                            1.000000
# 2019-02-04                            1.000000
# 2019-02-05                            1.000000
# 2019-02-06                            1.000000
# ...                                        ...
# 2024-01-31                            3.051878
# 2024-02-03                            3.051878
# 2024-02-04                            3.051878
# 2024-02-05                            3.051878
# 2024-02-06                            3.051878
#
# category_id  Свинина (кроме бескостного мяса)  \
# date
# 2019-02-01                           1.000000
# 2019-02-02                           0.993345
# 2019-02-04                           0.986735
# 2019-02-05                           0.980168
# 2019-02-06                           0.980168
# ...                                       ...
# 2024-01-31                           1.392277
# ...

# %%
pvt_df[pvt_df.columns[pvt_df.columns.str.contains('Хлеб|Сахар|подсол')]].to_excel('./plots/oil_sugar_bread.xlsx')
